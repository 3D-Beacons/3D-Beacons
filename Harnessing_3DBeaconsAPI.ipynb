# %% [markdown]
# <a href="https://colab.research.google.com/github/paulynamagana/3D-Beacons/blob/main/Harnessing_3DBeaconsAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Accessing data though 3D-Beacons API
#
# <img src="https://raw.githubusercontent.com/3D-Beacons/3D-Beacons/main/assets/3D-Beacons-logo.png" height="100" align="right">
#
# ## Introduction
#
# Welcome to this Google Colab notebook, an essential companion to our paper on accessing data through the 3D-Beacons API.
#
# This notebook serves as a practical resource for researchers, developers, and data enthusiasts who are interested in exploring the potential of the 3D-Beacons API and leveraging its capabilities. By following this guide, you will gain a deep understanding of how to interact with the 3D-Beacons API to access and analyze various types of data.
# To supplement your learning, we have provided links to the full paper as well as documentation resources that will assist you in navigating the API effectively.
#
# Paper Link: Accessing Data through 3DBEacons API - Full Paper
# ** TO LINK IT TO THE PAPER**
#
# Documentation Link: [3D-Beacons API Documentation](https://www.ebi.ac.uk/pdbe/pdbe-kb/3dbeacons/api/#/default/get_uniprot_summary_uniprot_summary__qualifier__json_get)
#
# <br>
#
# **Further readings:**
#
# **3D-Beacons: Decreasing the gap between protein sequences and structures through a federated network of protein structure data resources**
#
# Mihaly Varadi, Sreenath Nair, Ian Sillitoe, Gerardo Tauriello, Stephen Anyango, Stefan Bienert, Clemente Borges, Mandar Deshpande, Tim Green, Demis Hassabis, Andras Hatos, Tamas Hegedus, Maarten L Hekkelman, Robbie Joosten, John Jumper, Agata Laydon, Dmitry Molodenskiy, Damiano Piovesan, Edoardo Salladini, Steven L. Salzberg, Markus J Sommer, Martin Steinegger, Erzsebet Suhajda, Dmitri Svergun, Luiggi Tenorio-Ku, Silvio Tosatto, Kathryn Tunyasuvunakool, Andrew Mark Waterhouse, Augustin Žídek, Torsten Schwede, Christine Orengo, Sameer Velankar
# 3 August 2022; BioRxiv https://doi.org/10.1101/2022.08.01.501973

# %% [markdown]
#   ## Instructions <a name="Instructions"></a>
#
# * Quick Start <a name="Quick Start"></a>
#
# In order to make the learning experience more accessible and interactive, we have incorporated widgets that allow you to provide inputs and customize certain aspects of the code. These widgets serve as interactive elements that enhance your ability to interact with the code and observe the impact of different inputs on the results. Throughout this tutorial, you will come across code chunks that include these interactive widgets.
#
#   * How to use Google Colab <a name="Google Colab"></a>
# 1. To run a code cell, click on the cell to select it. You will notice a play button (▶️) on the left side of the cell. Click on the play button or press Shift+Enter to run the code in the selected cell.
# 2. The code will start executing, and you will see the output, if any, displayed below the code cell.
# 3. Move to the next code cell and repeat steps 2 and 3 until you have executed all the desired code cells in sequence.
# 4. The currently running step is indicated by a circle with a stop sign next to it.
# If you need to stop or interrupt the execution of a code cell, you can click on the stop button (■) located next to the play button.
#
# *Remember to run the code cells in the correct order, as their execution might depend on variables or functions defined in previous cells. You can modify the code in a code cell and re-run it to see updated results.*
#
# ## Contact us
#
# Requests for clarifications or reporting bugs can be made via pdbekb_help@ebi.ac.uk.

# %% [markdown]
# ## &nbsp; Set up
#
# * The code below will install and import all neccessary packages.
# * We have defined functions for easier functionality.

# %%
#@title Install dependencies
# !pip install ijson gwpy &> /dev/null

# %% [markdown]
# * After running the next code, you may be prompted to grant access to your Google Drive. This is necessary for Google Colab to download the files and save them to your Drive.
# <br>
# <br>
# Please follow the on-screen instructions to provide the necessary permissions, as it enables seamless integration between Colab and your Drive. Rest assured that your data and files are secure and will not be accessed without your explicit permission.
# <br>

# %%
#@title Initialise
## function for searching in the 3D Beacons Network
import ijson
import requests, sys, json
import ipywidgets as wgt
from urllib.request import urlopen
# Importing the necessary libraries: os for interacting with the operating system, and drive from google.colab for mounting Google Drive
import os
from google.colab import drive

# Mounting the Google Drive to access files and directories
drive.mount('/content/drive')
destination_path = '/content/drive/MyDrive/3D_Beacons_files'

# Check whether the specified path exists or not
isExist = os.path.exists(destination_path)
if not isExist:

   # Create a new directory because it does not exist
   os.makedirs(destination_path)
   print("The new directory is created!")

#defining functions for search and download
def Search3DBeacons(ID):
  WEBSITE_API = "https://www.ebi.ac.uk/pdbe/pdbe-kb/3dbeacons/api/uniprot/summary/"

  r = ijson.parse(urlopen(f"{WEBSITE_API}{ID}.json"))
  structures = list(ijson.items(r, "structures.item", use_float=True))
  return structures

# Function to download a file from a given URL and save it to the Google Drive
def download_file(url):
  os.chdir(destination_path)
  # !wget "$url"

#Defining UniProt ID
Uniprot_ID = wgt.Textarea(
    value= "",
    placeholder='Uniprot ID',
    description='Enter an Uniprot ID:',
    style={'description_width': 'initial'},
    disabled=False
)

#Defining all model type
model_type = wgt.Textarea(
    value="",
    placeholder='Enter model category',
    description='Enter a model type:',
    style={'description_width': 'initial'},
    disabled=False
)

#create a widget for provider
provider_value = wgt.Textarea(
    value="",
    placeholder='Enter  provider',
    description='Enter a provider:',
    style={'description_width': 'initial'},
    disabled=False
)

#create a widget for resolution
resolution_filter = wgt.FloatSlider(
    value=2.0,
    min=0,
    max=5.0,
    step=0.1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)

#create a widget to download specific model
model_download = wgt.Textarea(
    value="",
    placeholder='Enter model identifier',
    description='Model identifier:',
    style={'description_width': 'initial'},
    disabled=False
)


#endpoint
WEBSITE_API = "https://www.ebi.ac.uk/pdbe/pdbe-kb/3dbeacons/api/uniprot/summary/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##1.&nbsp; Basic search

# %% [markdown]
# ### 1.1.&nbsp;  Get all macromolecular structures for a single entry
#
#   The following block retrieves all available structures in 3D-Beacons from a single Uniprot accession ID.

# %%
#widget Uniprot ID
display(Uniprot_ID) #display the widget
# Out:
# Textarea(value='', description='Enter an Uniprot ID:', placeholder='Uniprot ID', style=DescriptionStyle(descri…

# %%
#define API endpoint
structures = Search3DBeacons(Uniprot_ID.value)

#print available structures from different providers
for structure in structures:
    print(structure)
# Out:
# {'summary': {'model_identifier': '3d06', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3d06_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3d06', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-05-01', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.2'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5mhc', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5mhc_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5mhc', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-11-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.2'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'LYS-LEU-MET-PHE-LYS-TPO-GLU-GLY-PRO-ASP-SER-ASP', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CA', 'identifier_category': 'CCD', 'description': 'CALCIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggc', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggc_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggc', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.24'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXN', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(furan-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6shz', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6shz_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6shz', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-08', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 311, 'coverage': Decimal('0.555'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.24'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '4mzi', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/4mzi_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/4mzi', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2013-09-30', 'sequence_identity': Decimal('92.0'), 'uniprot_start': 93, 'uniprot_end': 292, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.25'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6gge', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6gge_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6gge', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.25000506704'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EYE', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(5-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '3lw1', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3lw1_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3lw1', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2010-02-23', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 385, 'uniprot_end': 393, 'coverage': Decimal('0.023'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.28'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'peptide of Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '8e7a', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8e7a_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8e7a', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-08-23', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 93, 'uniprot_end': 312, 'coverage': Decimal('0.56'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5o1e', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1e_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1e', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GT', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-prop-2-enoxy-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6rl3', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6rl3_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6rl3', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-05-01', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'K48', 'identifier_category': 'CCD', 'description': '5-azanyl-4-phenyl-thiophene-2-carboximidamide', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggb', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggb_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggb', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EPE', 'identifier_category': 'CCD', 'description': '4-(2-HYDROXYETHYL)-1-PIPERAZINE ETHANESULFONIC ACID', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXQ', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(4-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1c', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1c_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1c', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GZ', 'identifier_category': 'CCD', 'description': '5-(4-fluorophenyl)-3-iodanyl-2-oxidanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1h', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1h_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1h', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GN', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-propylsulfanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '7b4n', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/7b4n_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/7b4n', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2020-12-02', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'FMT', 'identifier_category': 'CCD', 'description': 'FORMIC ACID', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QN8', 'identifier_category': 'CCD', 'description': '(2~{R})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QNN', 'identifier_category': 'CCD', 'description': '(2~{S})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': None, 'identifier': None, 'identifier_category': None, 'description': 'DNA target', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '6ggf', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggf_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggf', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32000022323'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXQ', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(4-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '3zme', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3zme_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3zme', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2013-02-07', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QC5', 'identifier_category': 'CCD', 'description': '2-(4-(4-fluorophenyl)-5-(1H-pyrrol-1-yl)-1H-pyrazol-1-yl)-N,N-dimethylethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5aok', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5aok_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5aok', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-09-10', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOH', 'identifier_category': 'CCD', 'description': '5-[2-cyclopropyl-5-(1H-pyrrol-1-yl)-1,3-oxazol-4-yl]-1H-1,2,3,4-tetrazole', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5g4n', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5g4n_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5g4n', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-05-13', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'O83', 'identifier_category': 'CCD', 'description': '1-[9-(2,2-difluoroethyl)-9H-carbazol-3-yl]-N-methylmethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1g', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1g_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1g', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GK', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-(2-phenylethoxy)-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6v4f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6v4f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6v4f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-11-27', 'sequence_identity': Decimal('81.0'), 'uniprot_start': 14, 'uniprot_end': 29, 'coverage': Decimal('0.041'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Stapled Peptide LSQETF(0EH)DLWKLE(MK8)EN(NH2)', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q7ZUW7', 'identifier_category': 'UNIPROT', 'description': 'Protein Mdm4', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'SO4', 'identifier_category': 'CCD', 'description': 'SULFATE ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5ab9', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5ab9_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5ab9', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-08-04', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.36'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '92O', 'identifier_category': 'CCD', 'description': '7-ethyl-3-(piperidin-4-yl)-1H-indole', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1d', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1d_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1d', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.36'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GW', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-propoxy-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '8a92', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8a92_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8a92', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-06-27', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.37'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LE9', 'identifier_category': 'CCD', 'description': '4-bromanyl-5-(trifluoromethyl)-1H-pyrazol-3-amine', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EPE', 'identifier_category': 'CCD', 'description': '4-(2-HYDROXYETHYL)-1-PIPERAZINE ETHANESULFONIC ACID', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5g4m', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5g4m_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5g4m', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-05-13', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.38'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'O82', 'identifier_category': 'CCD', 'description': '1-[9-(2-fluoroethyl)-9H-carbazol-3-yl]-N-methylmethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.38'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GQ', 'identifier_category': 'CCD', 'description': '5-butoxy-3-iodanyl-2-oxidanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '7b4h', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/7b4h_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/7b4h', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2020-12-02', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.39'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ACT', 'identifier_category': 'CCD', 'description': 'ACETATE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'FMT', 'identifier_category': 'CCD', 'description': 'FORMIC ACID', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QN8', 'identifier_category': 'CCD', 'description': '(2~{R})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QNN', 'identifier_category': 'CCD', 'description': '(2~{S})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': None, 'identifier': None, 'identifier_category': None, 'description': 'DNA target', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '5a7b', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5a7b_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5a7b', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-07-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'KMN', 'identifier_category': 'CCD', 'description': '2-[[4-(diethylamino)piperidin-1-yl]methyl]-6-ethynyl-4-(3-phenoxyprop-1-ynyl)phenol', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6si3', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6si3_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6si3', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-08', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LEB', 'identifier_category': 'CCD', 'description': '1-[7-bromanyl-9-[2,2,2-tris(fluoranyl)ethyl]carbazol-3-yl]-~{N}-methyl-methanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1i', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1i_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1i', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GH', 'identifier_category': 'CCD', 'description': '2-(diethylamino)-6-iodanyl-5-oxidanyl-7-pyrrol-1-yl-1,3-benzothiazole-4-carboxylic acid', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '3d08', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3d08_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3d08', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-05-01', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '1yc5', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1yc5_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1yc5', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2004-12-21', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 372, 'uniprot_end': 389, 'coverage': Decimal('0.046'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53 peptide', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q9WYW0', 'identifier_category': 'UNIPROT', 'description': 'NAD-dependent deacetylase', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'NCA', 'identifier_category': 'CCD', 'description': 'NICOTINAMIDE', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggd', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggd_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggd', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4000088608'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EYB', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(1,2-oxazol-4-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# ...
# {'summary': {'model_identifier': '1jsp', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1jsp_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1jsp', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2001-08-17', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 367, 'uniprot_end': 386, 'coverage': Decimal('0.051'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'tumor protein p53', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q92793', 'identifier_category': 'UNIPROT', 'description': 'CREB-BINDING PROTEIN', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '2mwy', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwy_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwy', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-12-03', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 15, 'uniprot_end': 29, 'coverage': Decimal('0.038'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'O15151', 'identifier_category': 'UNIPROT', 'description': 'Protein Mdm4', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '2mwo', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwo_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwo', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-11-15', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 363, 'uniprot_end': 377, 'coverage': Decimal('0.038'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q12888', 'identifier_category': 'UNIPROT', 'description': 'Tumor suppressor p53-binding protein 1', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '2mwp', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwp_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwp', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-11-15', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 376, 'uniprot_end': 387, 'coverage': Decimal('0.031'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q12888', 'identifier_category': 'UNIPROT', 'description': 'Tumor suppressor p53-binding protein 1', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': 'PED00037e001', 'model_category': 'CONFORMATIONAL ENSEMBLE', 'model_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00037/ensembles/e001/ensemble-sample/', 'model_format': 'MMCIF', 'model_page_url': 'https://proteinensemble.org/entries/PED00037', 'provider': 'PED', 'number_of_conformers': Decimal('20.0'), 'ensemble_sample_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00037/ensembles/e001/ensemble-sample/', 'ensemble_sample_format': 'MMCIF', 'created': '2020-10-01', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 1, 'uniprot_end': 61, 'coverage': Decimal('0.15521628498727735'), 'entities': []}}
# {'summary': {'model_identifier': 'PED00038e001', 'model_category': 'CONFORMATIONAL ENSEMBLE', 'model_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00038/ensembles/e001/ensemble-sample/', 'model_format': 'MMCIF', 'model_page_url': 'https://proteinensemble.org/entries/PED00038', 'provider': 'PED', 'number_of_conformers': Decimal('20.0'), 'ensemble_sample_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00038/ensembles/e001/ensemble-sample/', 'ensemble_sample_format': 'MMCIF', 'created': '2020-10-01', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 2, 'uniprot_end': 61, 'coverage': Decimal('0.15267175572519084'), 'entities': []}}
# {'summary': {'model_identifier': 'PED00039e001', 'model_category': 'CONFORMATIONAL ENSEMBLE', 'model_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00039/ensembles/e001/ensemble-sample/', 'model_format': 'MMCIF', 'model_page_url': 'https://proteinensemble.org/entries/PED00039', 'provider': 'PED', 'number_of_conformers': Decimal('20.0'), 'ensemble_sample_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00039/ensembles/e001/ensemble-sample/', 'ensemble_sample_format': 'MMCIF', 'created': '2020-10-01', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 37, 'uniprot_end': 61, 'coverage': Decimal('0.06361323155216285'), 'entities': []}}
# {'summary': {'model_identifier': 'PED00063e001', 'model_category': 'CONFORMATIONAL ENSEMBLE', 'model_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00063/ensembles/e001/ensemble-sample/', 'model_format': 'MMCIF', 'model_page_url': 'https://proteinensemble.org/entries/PED00063', 'provider': 'PED', 'number_of_conformers': Decimal('40.0'), 'ensemble_sample_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00063/ensembles/e001/ensemble-sample/', 'ensemble_sample_format': 'MMCIF', 'created': '2020-10-01', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 367, 'uniprot_end': 388, 'coverage': Decimal('0.05597964376590331'), 'entities': []}}
# {'summary': {'model_identifier': 'PED00063e001', 'model_category': 'CONFORMATIONAL ENSEMBLE', 'model_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00063/ensembles/e001/ensemble-sample/', 'model_format': 'MMCIF', 'model_page_url': 'https://proteinensemble.org/entries/PED00063', 'provider': 'PED', 'number_of_conformers': Decimal('40.0'), 'ensemble_sample_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00063/ensembles/e001/ensemble-sample/', 'ensemble_sample_format': 'MMCIF', 'created': '2020-10-01', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 367, 'uniprot_end': 388, 'coverage': Decimal('0.05597964376590331'), 'entities': []}}
# {'summary': {'model_identifier': 'PED00064e001', 'model_category': 'CONFORMATIONAL ENSEMBLE', 'model_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00064/ensembles/e001/ensemble-sample/', 'model_format': 'MMCIF', 'model_page_url': 'https://proteinensemble.org/entries/PED00064', 'provider': 'PED', 'number_of_conformers': Decimal('20.0'), 'ensemble_sample_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00064/ensembles/e001/ensemble-sample/', 'ensemble_sample_format': 'MMCIF', 'created': '2020-10-01', 'sequence_identity': Decimal('0.95'), 'uniprot_start': 367, 'uniprot_end': 386, 'coverage': Decimal('0.05089058524173028'), 'entities': []}}
# {'summary': {'model_identifier': 'PED00087e001', 'model_category': 'CONFORMATIONAL ENSEMBLE', 'model_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00087/ensembles/e001/ensemble-sample/', 'model_format': 'MMCIF', 'model_page_url': 'https://proteinensemble.org/entries/PED00087', 'provider': 'PED', 'number_of_conformers': Decimal('20.0'), 'ensemble_sample_url': 'https://deposition.proteinensemble.org/api/v1/entries/PED00087/ensembles/e001/ensemble-sample/', 'ensemble_sample_format': 'MMCIF', 'created': '2020-10-01', 'sequence_identity': Decimal('0.25925925925925924'), 'uniprot_start': 20, 'uniprot_end': 73, 'coverage': Decimal('0.035623409669211195'), 'entities': []}}
# {'summary': {'model_identifier': 'P04637_94-355:3q05.1.A', 'model_category': 'TEMPLATE-BASED', 'model_url': 'https://swissmodel.expasy.org/3d-beacons/uniprot/P04637.pdb?range=94-355&template=3q05.1.A&provider=swissmodel', 'model_format': 'PDB', 'model_type': 'ATOMIC', 'model_page_url': 'https://swissmodel.expasy.org/repository/uniprot/P04637?range=94-355&template=3q05.1.A', 'provider': 'SWISS-MODEL', 'created': '2023-06-13', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 94, 'uniprot_end': 355, 'coverage': Decimal('0.667'), 'confidence_type': 'QMEANDisCo', 'confidence_version': '4.3.1', 'confidence_avg_local_score': Decimal('0.678'), 'oligomeric_state': 'MONOMER', 'entities': [{'entity_type': 'NON-POLYMER', 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['_']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'model based on template 3q05.1.A: Cellular tumor antigen p53', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': 'P04637_1-393:8f2h.1.B', 'model_category': 'TEMPLATE-BASED', 'model_url': 'https://swissmodel.expasy.org/3d-beacons/uniprot/P04637.pdb?range=1-393&template=8f2h.1.B&provider=swissmodel', 'model_format': 'PDB', 'model_type': 'ATOMIC', 'model_page_url': 'https://swissmodel.expasy.org/repository/uniprot/P04637?range=1-393&template=8f2h.1.B', 'provider': 'SWISS-MODEL', 'created': '2023-06-13', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 1, 'uniprot_end': 393, 'coverage': Decimal('1.0'), 'confidence_type': 'QMEANDisCo', 'confidence_version': '4.3.1', 'confidence_avg_local_score': Decimal('0.675'), 'oligomeric_state': 'MONOMER', 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'model based on template 8f2h.1.B: Cellular tumor antigen p53', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': 'P04637_94-356:3q01.1.B', 'model_category': 'TEMPLATE-BASED', 'model_url': 'https://swissmodel.expasy.org/3d-beacons/uniprot/P04637.pdb?range=94-356&template=3q01.1.B&provider=swissmodel', 'model_format': 'PDB', 'model_type': 'ATOMIC', 'model_page_url': 'https://swissmodel.expasy.org/repository/uniprot/P04637?range=94-356&template=3q01.1.B', 'provider': 'SWISS-MODEL', 'created': '2023-06-13', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 94, 'uniprot_end': 356, 'coverage': Decimal('0.669'), 'confidence_type': 'QMEANDisCo', 'confidence_version': '4.3.1', 'confidence_avg_local_score': Decimal('0.67'), 'oligomeric_state': 'MONOMER', 'entities': [{'entity_type': 'NON-POLYMER', 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['_']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'model based on template 3q01.1.B: Cellular tumor antigen p53', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': 'P04637_12-351:6xre.1.M', 'model_category': 'TEMPLATE-BASED', 'model_url': 'https://swissmodel.expasy.org/3d-beacons/uniprot/P04637.pdb?range=12-351&template=6xre.1.M&provider=swissmodel', 'model_format': 'PDB', 'model_type': 'ATOMIC', 'model_page_url': 'https://swissmodel.expasy.org/repository/uniprot/P04637?range=12-351&template=6xre.1.M', 'provider': 'SWISS-MODEL', 'created': '2023-06-13', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 12, 'uniprot_end': 351, 'coverage': Decimal('0.865'), 'confidence_type': 'QMEANDisCo', 'confidence_version': '4.3.1', 'confidence_avg_local_score': Decimal('0.639'), 'oligomeric_state': 'MONOMER', 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'model based on template 6xre.1.M: Cellular tumor antigen p53', 'chain_ids': ['M']}]}}
# {'summary': {'model_identifier': 'AF-P04637-F1', 'model_category': 'AB-INITIO', 'model_url': 'https://alphafold.ebi.ac.uk/files/AF-P04637-F1-model_v4.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://alphafold.ebi.ac.uk/entry/P04637', 'provider': 'AlphaFold DB', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-06-01', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 1, 'uniprot_end': 393, 'coverage': Decimal('1.0'), 'experimental_method': None, 'resolution': None, 'confidence_type': 'pLDDT', 'confidence_version': None, 'confidence_avg_local_score': Decimal('74.33'), 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': 'P04637', 'model_category': 'TEMPLATE-BASED', 'model_url': 'https://alphafill.eu/v1/aff/P04637', 'model_format': 'MMCIF', 'model_page_url': 'https://alphafill.eu/model?id=P04637', 'provider': 'AlphaFill', 'created': '2022-05-04', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 1, 'uniprot_end': 393, 'coverage': Decimal('1.0'), 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'description': 'ZINC ION', 'chain_ids': ['B', 'E']}, {'entity_type': 'NON-POLYMER', 'description': 'FORMYL GROUP', 'chain_ids': ['C', 'D']}, {'entity_type': 'NON-POLYMER', 'description': 'ARSENIC', 'chain_ids': ['F']}]}}
# {'summary': {'model_identifier': 'CHS.21217.5', 'model_category': 'AB-INITIO', 'model_url': 'https://storage.googleapis.com/isoform.io/pdb/CHS.21217.5.pdb', 'model_format': 'PDB', 'provider': 'isoform.io', 'created': '2022-06-05', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 1, 'uniprot_end': 393, 'coverage': Decimal('1.0'), 'entities': [{'entity_type': 'POLYMER', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': 'CHS.21217.4', 'model_category': 'AB-INITIO', 'model_url': 'https://storage.googleapis.com/isoform.io/pdb/CHS.21217.4.pdb', 'model_format': 'PDB', 'provider': 'isoform.io', 'created': '2022-06-05', 'sequence_identity': Decimal('1.0'), 'uniprot_start': 1, 'uniprot_end': 393, 'coverage': Decimal('1.0'), 'entities': [{'entity_type': 'POLYMER', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}]}}

# %% [markdown]
# ### 1.2.&nbsp;  Performing one  filter

# %% [markdown]
# #### 1.2.1.&nbsp; Filter by Model type
# Results can be filtered according to the model category in the 3D-Beacons Network.
# Models are classified as:
#
# * EXPERIMENTALLY DETERMINED
# * CONFORMATIONAL ENSEMBLE
# * TEMPLATE-BASED
# * AB-INITIO
#
# Code below allows you to filter the previous search using a model category.

# %%
#Run this code to create a widget for input
display(model_type) #display widget
# Out:
# Textarea(value='', description='Enter a model type:', placeholder='Enter model category', style=DescriptionSty…

# %%
#filter for experimental structures according to model category
for structure in structures:
    model_category = structure.get('summary', {}).get('model_category')
    if model_category == model_type.value:
        print(structure)
# Out:
# {'summary': {'model_identifier': '3d06', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3d06_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3d06', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-05-01', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.2'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5mhc', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5mhc_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5mhc', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-11-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.2'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'LYS-LEU-MET-PHE-LYS-TPO-GLU-GLY-PRO-ASP-SER-ASP', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CA', 'identifier_category': 'CCD', 'description': 'CALCIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggc', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggc_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggc', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.24'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXN', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(furan-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6shz', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6shz_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6shz', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-08', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 311, 'coverage': Decimal('0.555'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.24'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '4mzi', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/4mzi_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/4mzi', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2013-09-30', 'sequence_identity': Decimal('92.0'), 'uniprot_start': 93, 'uniprot_end': 292, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.25'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6gge', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6gge_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6gge', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.25000506704'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EYE', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(5-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '3lw1', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3lw1_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3lw1', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2010-02-23', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 385, 'uniprot_end': 393, 'coverage': Decimal('0.023'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.28'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'peptide of Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '8e7a', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8e7a_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8e7a', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-08-23', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 93, 'uniprot_end': 312, 'coverage': Decimal('0.56'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5o1e', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1e_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1e', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GT', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-prop-2-enoxy-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6rl3', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6rl3_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6rl3', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-05-01', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'K48', 'identifier_category': 'CCD', 'description': '5-azanyl-4-phenyl-thiophene-2-carboximidamide', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggb', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggb_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggb', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EPE', 'identifier_category': 'CCD', 'description': '4-(2-HYDROXYETHYL)-1-PIPERAZINE ETHANESULFONIC ACID', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXQ', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(4-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1c', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1c_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1c', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GZ', 'identifier_category': 'CCD', 'description': '5-(4-fluorophenyl)-3-iodanyl-2-oxidanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1h', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1h_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1h', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GN', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-propylsulfanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '7b4n', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/7b4n_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/7b4n', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2020-12-02', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'FMT', 'identifier_category': 'CCD', 'description': 'FORMIC ACID', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QN8', 'identifier_category': 'CCD', 'description': '(2~{R})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QNN', 'identifier_category': 'CCD', 'description': '(2~{S})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': None, 'identifier': None, 'identifier_category': None, 'description': 'DNA target', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '6ggf', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggf_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggf', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32000022323'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXQ', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(4-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '3zme', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3zme_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3zme', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2013-02-07', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QC5', 'identifier_category': 'CCD', 'description': '2-(4-(4-fluorophenyl)-5-(1H-pyrrol-1-yl)-1H-pyrazol-1-yl)-N,N-dimethylethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5aok', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5aok_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5aok', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-09-10', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOH', 'identifier_category': 'CCD', 'description': '5-[2-cyclopropyl-5-(1H-pyrrol-1-yl)-1,3-oxazol-4-yl]-1H-1,2,3,4-tetrazole', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5g4n', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5g4n_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5g4n', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-05-13', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'O83', 'identifier_category': 'CCD', 'description': '1-[9-(2,2-difluoroethyl)-9H-carbazol-3-yl]-N-methylmethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1g', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1g_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1g', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GK', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-(2-phenylethoxy)-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6v4f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6v4f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6v4f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-11-27', 'sequence_identity': Decimal('81.0'), 'uniprot_start': 14, 'uniprot_end': 29, 'coverage': Decimal('0.041'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Stapled Peptide LSQETF(0EH)DLWKLE(MK8)EN(NH2)', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q7ZUW7', 'identifier_category': 'UNIPROT', 'description': 'Protein Mdm4', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'SO4', 'identifier_category': 'CCD', 'description': 'SULFATE ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5ab9', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5ab9_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5ab9', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-08-04', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.36'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '92O', 'identifier_category': 'CCD', 'description': '7-ethyl-3-(piperidin-4-yl)-1H-indole', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1d', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1d_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1d', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.36'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GW', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-propoxy-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '8a92', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8a92_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8a92', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-06-27', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.37'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LE9', 'identifier_category': 'CCD', 'description': '4-bromanyl-5-(trifluoromethyl)-1H-pyrazol-3-amine', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EPE', 'identifier_category': 'CCD', 'description': '4-(2-HYDROXYETHYL)-1-PIPERAZINE ETHANESULFONIC ACID', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5g4m', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5g4m_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5g4m', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-05-13', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.38'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'O82', 'identifier_category': 'CCD', 'description': '1-[9-(2-fluoroethyl)-9H-carbazol-3-yl]-N-methylmethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.38'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GQ', 'identifier_category': 'CCD', 'description': '5-butoxy-3-iodanyl-2-oxidanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '7b4h', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/7b4h_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/7b4h', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2020-12-02', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.39'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ACT', 'identifier_category': 'CCD', 'description': 'ACETATE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'FMT', 'identifier_category': 'CCD', 'description': 'FORMIC ACID', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QN8', 'identifier_category': 'CCD', 'description': '(2~{R})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QNN', 'identifier_category': 'CCD', 'description': '(2~{S})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': None, 'identifier': None, 'identifier_category': None, 'description': 'DNA target', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '5a7b', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5a7b_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5a7b', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-07-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'KMN', 'identifier_category': 'CCD', 'description': '2-[[4-(diethylamino)piperidin-1-yl]methyl]-6-ethynyl-4-(3-phenoxyprop-1-ynyl)phenol', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6si3', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6si3_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6si3', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-08', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LEB', 'identifier_category': 'CCD', 'description': '1-[7-bromanyl-9-[2,2,2-tris(fluoranyl)ethyl]carbazol-3-yl]-~{N}-methyl-methanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1i', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1i_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1i', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GH', 'identifier_category': 'CCD', 'description': '2-(diethylamino)-6-iodanyl-5-oxidanyl-7-pyrrol-1-yl-1,3-benzothiazole-4-carboxylic acid', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '3d08', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3d08_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3d08', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-05-01', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '1yc5', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1yc5_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1yc5', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2004-12-21', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 372, 'uniprot_end': 389, 'coverage': Decimal('0.046'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53 peptide', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q9WYW0', 'identifier_category': 'UNIPROT', 'description': 'NAD-dependent deacetylase', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'NCA', 'identifier_category': 'CCD', 'description': 'NICOTINAMIDE', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggd', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggd_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggd', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4000088608'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EYB', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(1,2-oxazol-4-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# ...
# {'summary': {'model_identifier': '2k8f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2k8f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2k8f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-09-08', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 1, 'uniprot_end': 39, 'coverage': Decimal('0.099'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q09472', 'identifier_category': 'UNIPROT', 'description': 'Histone acetyltransferase p300', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '1a1u', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1a1u_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1a1u', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '1997-12-16', 'sequence_identity': Decimal('91.0'), 'uniprot_start': 324, 'uniprot_end': 358, 'coverage': Decimal('0.089'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'P53', 'chain_ids': ['A', 'C']}]}}
# {'summary': {'model_identifier': '1hs5', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1hs5_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1hs5', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2000-12-22', 'sequence_identity': Decimal('94.0'), 'uniprot_start': 324, 'uniprot_end': 357, 'coverage': Decimal('0.087'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '2j11', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2j11_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2j11', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2006-08-08', 'sequence_identity': Decimal('90.0'), 'uniprot_start': 326, 'uniprot_end': 356, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '2j10', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2j10_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2j10', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2006-08-08', 'sequence_identity': Decimal('94.0'), 'uniprot_start': 326, 'uniprot_end': 356, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '2j0z', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2j0z_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2j0z', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2006-08-08', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 326, 'uniprot_end': 356, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '1pes', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1pes_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1pes', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '1994-11-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 325, 'uniprot_end': 355, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'TUMOR SUPPRESSOR P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '1pet', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1pet_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1pet', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '1994-11-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 325, 'uniprot_end': 355, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'TUMOR SUPPRESSOR P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '2mzd', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mzd_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mzd', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-02-11', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 35, 'uniprot_end': 59, 'coverage': Decimal('0.064'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q09472', 'identifier_category': 'UNIPROT', 'description': 'Histone acetyltransferase p300', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5hp0', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5hp0_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5hp0', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-01-19', 'sequence_identity': Decimal('71.0'), 'uniprot_start': 37, 'uniprot_end': 61, 'coverage': Decimal('0.064'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CREB-binding protein,Cellular tumor antigen p53 fusion protein', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P45481', 'identifier_category': 'UNIPROT', 'description': 'CREB-binding protein,Cellular tumor antigen p53 fusion protein', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '2ruk', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2ruk_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2ruk', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-09-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 41, 'uniprot_end': 62, 'coverage': Decimal('0.056'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P32780', 'identifier_category': 'UNIPROT', 'description': 'General transcription factor IIH subunit 1', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '1jsp', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1jsp_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1jsp', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2001-08-17', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 367, 'uniprot_end': 386, 'coverage': Decimal('0.051'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'tumor protein p53', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q92793', 'identifier_category': 'UNIPROT', 'description': 'CREB-BINDING PROTEIN', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '2mwy', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwy_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwy', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-12-03', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 15, 'uniprot_end': 29, 'coverage': Decimal('0.038'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'O15151', 'identifier_category': 'UNIPROT', 'description': 'Protein Mdm4', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '2mwo', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwo_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwo', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-11-15', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 363, 'uniprot_end': 377, 'coverage': Decimal('0.038'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q12888', 'identifier_category': 'UNIPROT', 'description': 'Tumor suppressor p53-binding protein 1', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '2mwp', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwp_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwp', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-11-15', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 376, 'uniprot_end': 387, 'coverage': Decimal('0.031'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q12888', 'identifier_category': 'UNIPROT', 'description': 'Tumor suppressor p53-binding protein 1', 'chain_ids': ['A']}]}}

# %% [markdown]
# #### 1.2.2.&nbsp; Filter by Provider
#
# The 3D-Beacons Network facilitates the aggregation of coordinate files and metadata for both experimental and theoretical protein models. It encompasses a wide range of state-of-the-art and specialized model providers, as well as data from the European Protein Data Bank (PDBe).
#
# Model providers:
# * PDBe
# * SWISS-MODEL
# * AlphaFold DB
# * Genome3D
# * SASBDB
# * AlphaFill
# * ModelArchive
# * Protein Ensemble Database

# %%
#widget
display(provider_value)
# Out:
# Textarea(value='', description='Enter a provider:', placeholder='Enter  provider', style=DescriptionStyle(desc…

# %%
#filter for experimental structures for PDBe
for structure in structures:
    provider = structure.get('summary', {}).get('provider')

    if provider == provider_value.value:
        print(structure)
# Out:
# {'summary': {'model_identifier': '3d06', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3d06_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3d06', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-05-01', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.2'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5mhc', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5mhc_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5mhc', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-11-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.2'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'LYS-LEU-MET-PHE-LYS-TPO-GLU-GLY-PRO-ASP-SER-ASP', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CA', 'identifier_category': 'CCD', 'description': 'CALCIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggc', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggc_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggc', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.24'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXN', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(furan-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6shz', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6shz_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6shz', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-08', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 311, 'coverage': Decimal('0.555'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.24'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '4mzi', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/4mzi_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/4mzi', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2013-09-30', 'sequence_identity': Decimal('92.0'), 'uniprot_start': 93, 'uniprot_end': 292, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.25'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6gge', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6gge_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6gge', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.25000506704'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EYE', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(5-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '3lw1', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3lw1_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3lw1', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2010-02-23', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 385, 'uniprot_end': 393, 'coverage': Decimal('0.023'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.28'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'peptide of Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '8e7a', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8e7a_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8e7a', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-08-23', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 93, 'uniprot_end': 312, 'coverage': Decimal('0.56'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5o1e', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1e_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1e', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GT', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-prop-2-enoxy-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6rl3', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6rl3_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6rl3', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-05-01', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'K48', 'identifier_category': 'CCD', 'description': '5-azanyl-4-phenyl-thiophene-2-carboximidamide', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggb', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggb_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggb', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EPE', 'identifier_category': 'CCD', 'description': '4-(2-HYDROXYETHYL)-1-PIPERAZINE ETHANESULFONIC ACID', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXQ', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(4-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1c', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1c_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1c', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GZ', 'identifier_category': 'CCD', 'description': '5-(4-fluorophenyl)-3-iodanyl-2-oxidanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1h', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1h_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1h', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GN', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-propylsulfanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '7b4n', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/7b4n_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/7b4n', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2020-12-02', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'FMT', 'identifier_category': 'CCD', 'description': 'FORMIC ACID', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QN8', 'identifier_category': 'CCD', 'description': '(2~{R})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QNN', 'identifier_category': 'CCD', 'description': '(2~{S})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': None, 'identifier': None, 'identifier_category': None, 'description': 'DNA target', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '6ggf', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggf_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggf', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32000022323'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXQ', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(4-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '3zme', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3zme_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3zme', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2013-02-07', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QC5', 'identifier_category': 'CCD', 'description': '2-(4-(4-fluorophenyl)-5-(1H-pyrrol-1-yl)-1H-pyrazol-1-yl)-N,N-dimethylethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5aok', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5aok_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5aok', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-09-10', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOH', 'identifier_category': 'CCD', 'description': '5-[2-cyclopropyl-5-(1H-pyrrol-1-yl)-1,3-oxazol-4-yl]-1H-1,2,3,4-tetrazole', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5g4n', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5g4n_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5g4n', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-05-13', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'O83', 'identifier_category': 'CCD', 'description': '1-[9-(2,2-difluoroethyl)-9H-carbazol-3-yl]-N-methylmethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1g', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1g_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1g', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GK', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-(2-phenylethoxy)-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6v4f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6v4f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6v4f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-11-27', 'sequence_identity': Decimal('81.0'), 'uniprot_start': 14, 'uniprot_end': 29, 'coverage': Decimal('0.041'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Stapled Peptide LSQETF(0EH)DLWKLE(MK8)EN(NH2)', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q7ZUW7', 'identifier_category': 'UNIPROT', 'description': 'Protein Mdm4', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'SO4', 'identifier_category': 'CCD', 'description': 'SULFATE ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5ab9', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5ab9_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5ab9', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-08-04', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.36'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '92O', 'identifier_category': 'CCD', 'description': '7-ethyl-3-(piperidin-4-yl)-1H-indole', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1d', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1d_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1d', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.36'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GW', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-propoxy-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '8a92', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8a92_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8a92', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-06-27', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.37'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LE9', 'identifier_category': 'CCD', 'description': '4-bromanyl-5-(trifluoromethyl)-1H-pyrazol-3-amine', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EPE', 'identifier_category': 'CCD', 'description': '4-(2-HYDROXYETHYL)-1-PIPERAZINE ETHANESULFONIC ACID', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5g4m', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5g4m_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5g4m', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-05-13', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.38'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'O82', 'identifier_category': 'CCD', 'description': '1-[9-(2-fluoroethyl)-9H-carbazol-3-yl]-N-methylmethanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.38'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GQ', 'identifier_category': 'CCD', 'description': '5-butoxy-3-iodanyl-2-oxidanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '7b4h', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/7b4h_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/7b4h', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2020-12-02', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.39'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ACT', 'identifier_category': 'CCD', 'description': 'ACETATE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'FMT', 'identifier_category': 'CCD', 'description': 'FORMIC ACID', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QN8', 'identifier_category': 'CCD', 'description': '(2~{R})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QNN', 'identifier_category': 'CCD', 'description': '(2~{S})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': None, 'identifier': None, 'identifier_category': None, 'description': 'DNA target', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '5a7b', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5a7b_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5a7b', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-07-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'KMN', 'identifier_category': 'CCD', 'description': '2-[[4-(diethylamino)piperidin-1-yl]methyl]-6-ethynyl-4-(3-phenoxyprop-1-ynyl)phenol', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '6si3', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6si3_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6si3', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-08', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LEB', 'identifier_category': 'CCD', 'description': '1-[7-bromanyl-9-[2,2,2-tris(fluoranyl)ethyl]carbazol-3-yl]-~{N}-methyl-methanamine', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '5o1i', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1i_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1i', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GH', 'identifier_category': 'CCD', 'description': '2-(diethylamino)-6-iodanyl-5-oxidanyl-7-pyrrol-1-yl-1,3-benzothiazole-4-carboxylic acid', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '3d08', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3d08_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3d08', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-05-01', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '1yc5', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1yc5_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1yc5', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2004-12-21', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 372, 'uniprot_end': 389, 'coverage': Decimal('0.046'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53 peptide', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q9WYW0', 'identifier_category': 'UNIPROT', 'description': 'NAD-dependent deacetylase', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'NCA', 'identifier_category': 'CCD', 'description': 'NICOTINAMIDE', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '6ggd', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggd_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggd', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.4000088608'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EYB', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(1,2-oxazol-4-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# ...
# {'summary': {'model_identifier': '2k8f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2k8f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2k8f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-09-08', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 1, 'uniprot_end': 39, 'coverage': Decimal('0.099'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q09472', 'identifier_category': 'UNIPROT', 'description': 'Histone acetyltransferase p300', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '1a1u', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1a1u_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1a1u', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '1997-12-16', 'sequence_identity': Decimal('91.0'), 'uniprot_start': 324, 'uniprot_end': 358, 'coverage': Decimal('0.089'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'P53', 'chain_ids': ['A', 'C']}]}}
# {'summary': {'model_identifier': '1hs5', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1hs5_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1hs5', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2000-12-22', 'sequence_identity': Decimal('94.0'), 'uniprot_start': 324, 'uniprot_end': 357, 'coverage': Decimal('0.087'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}]}}
# {'summary': {'model_identifier': '2j11', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2j11_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2j11', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2006-08-08', 'sequence_identity': Decimal('90.0'), 'uniprot_start': 326, 'uniprot_end': 356, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '2j10', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2j10_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2j10', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2006-08-08', 'sequence_identity': Decimal('94.0'), 'uniprot_start': 326, 'uniprot_end': 356, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '2j0z', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2j0z_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2j0z', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2006-08-08', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 326, 'uniprot_end': 356, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '1pes', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1pes_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1pes', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '1994-11-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 325, 'uniprot_end': 355, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'TUMOR SUPPRESSOR P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '1pet', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1pet_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1pet', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '1994-11-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 325, 'uniprot_end': 355, 'coverage': Decimal('0.079'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'TUMOR SUPPRESSOR P53', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# {'summary': {'model_identifier': '2mzd', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mzd_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mzd', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-02-11', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 35, 'uniprot_end': 59, 'coverage': Decimal('0.064'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q09472', 'identifier_category': 'UNIPROT', 'description': 'Histone acetyltransferase p300', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '5hp0', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5hp0_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5hp0', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-01-19', 'sequence_identity': Decimal('71.0'), 'uniprot_start': 37, 'uniprot_end': 61, 'coverage': Decimal('0.064'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CREB-binding protein,Cellular tumor antigen p53 fusion protein', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P45481', 'identifier_category': 'UNIPROT', 'description': 'CREB-binding protein,Cellular tumor antigen p53 fusion protein', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '2ruk', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2ruk_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2ruk', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-09-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 41, 'uniprot_end': 62, 'coverage': Decimal('0.056'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P32780', 'identifier_category': 'UNIPROT', 'description': 'General transcription factor IIH subunit 1', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '1jsp', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/1jsp_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/1jsp', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2001-08-17', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 367, 'uniprot_end': 386, 'coverage': Decimal('0.051'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'tumor protein p53', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q92793', 'identifier_category': 'UNIPROT', 'description': 'CREB-BINDING PROTEIN', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '2mwy', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwy_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwy', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-12-03', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 15, 'uniprot_end': 29, 'coverage': Decimal('0.038'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'O15151', 'identifier_category': 'UNIPROT', 'description': 'Protein Mdm4', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}]}}
# {'summary': {'model_identifier': '2mwo', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwo_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwo', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-11-15', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 363, 'uniprot_end': 377, 'coverage': Decimal('0.038'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q12888', 'identifier_category': 'UNIPROT', 'description': 'Tumor suppressor p53-binding protein 1', 'chain_ids': ['A']}]}}
# {'summary': {'model_identifier': '2mwp', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2mwp_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2mwp', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2014-11-15', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 376, 'uniprot_end': 387, 'coverage': Decimal('0.031'), 'experimental_method': 'SOLUTION NMR', 'resolution': None, 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q12888', 'identifier_category': 'UNIPROT', 'description': 'Tumor suppressor p53-binding protein 1', 'chain_ids': ['A']}]}}

# %% [markdown]
# ### 1.3.&nbsp;  Performing two filters

# %% [markdown]
# #### 1.3.1&nbsp;  Filter by Model type and Coverage
#
# The code below will filter all the structures from a Uniprot ID and will save the model with the highest coverage to Google Drive.

# %%
display(Uniprot_ID) #display widget for UniProt ID
display(model_type)
# Out:
# Textarea(value='P04637', description='Enter an Uniprot ID:', placeholder='Uniprot ID', style=DescriptionStyle(…
# Textarea(value='EXPERIMENTALLY DETERMINED', description='Enter a model type:', placeholder='Enter model catego…

# %%
response = urlopen(f"{WEBSITE_API}{Uniprot_ID.value}.json")
r = ijson.parse(response)
structures = list(ijson.items(r, "structures.item", use_float=True))
structures.sort(key=lambda x: x.get('summary', {}).get('coverage', 0), reverse=True)

highest_coverage_structure = None
for structure in structures:
    model_category = structure.get('summary', {}).get('model_category')
    if model_category == model_type.value:
        highest_coverage_structure = structure
        break

if highest_coverage_structure is not None:
    print(highest_coverage_structure)

model_download = highest_coverage_structure.get('summary', {}).get('model_identifier')
for structure in structures:
    model = structure.get('summary', {}).get('model_identifier')
    if model == model_download:
        model_url = structure.get("summary", {}).get("model_url")
        download_file(model_url)
# Out:
# {'summary': {'model_identifier': '7xzz', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/7xzz_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/7xzz', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-06-03', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 1, 'uniprot_end': 393, 'coverage': Decimal('1.0'), 'experimental_method': 'ELECTRON MICROSCOPY', 'resolution': Decimal('4.07'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['N', 'L', 'K', 'M']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04908', 'identifier_category': 'UNIPROT', 'description': 'Histone H2A type 1-B/E', 'chain_ids': ['C', 'G']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P06899', 'identifier_category': 'UNIPROT', 'description': 'Histone H2B type 1-J', 'chain_ids': ['D', 'H']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P62805', 'identifier_category': 'UNIPROT', 'description': 'Histone H4', 'chain_ids': ['B', 'F']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P68431', 'identifier_category': 'UNIPROT', 'description': 'Histone H3.1', 'chain_ids': ['A', 'E']}, {'entity_type': 'POLYMER', 'entity_poly_type': None, 'identifier': None, 'identifier_category': None, 'description': 'DNA (169-MER)', 'chain_ids': ['J', 'I']}]}}
# --2023-06-13 15:59:00--  https://www.ebi.ac.uk/pdbe/static/entry/7xzz_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2384701 (2.3M) [text/plain]
# Saving to: ‘7xzz_updated.cif’
#
# 7xzz_updated.cif    100%[===================>]   2.27M   479KB/s    in 6.3s
#
# 2023-06-13 15:59:08 (370 KB/s) - ‘7xzz_updated.cif’ saved [2384701/2384701]

# %% [markdown]
# #### 1.3.2&nbsp;  Filter by model type and retrieve results according to resolution.
#
#
# The code below will filter all the structures from a Uniprot ID and will save the models with a resolution higher than the specified on the widget.

# %%
#display widgets
display(Uniprot_ID)
display(provider_value)
display(resolution_filter)
# Out:
# Textarea(value='', description='Enter an Uniprot ID:', placeholder='Uniprot ID', style=DescriptionStyle(descri…
# Textarea(value='', description='Enter a provider:', placeholder='Enter  provider', style=DescriptionStyle(desc…
# FloatSlider(value=2.0, continuous_update=False, description='Test:', max=5.0, readout_format='.1f')

# %%
r = ijson.parse(urlopen(f"{WEBSITE_API}{Uniprot_ID.value}.json")) #build
structures = list(ijson.items(r, "structures.item", use_float=True))

#filter for experimental structures
high_resolution_structures = []
for structure in structures:
    provider = structure.get('summary', {}).get('provider')
    resolution = structure.get('summary', {}).get('resolution')

    if provider == provider_value.value and resolution is not None and resolution < resolution_filter.value:
        # Append the structure to the list without assigning the result back to the list
        high_resolution_structures.append(structure)

# Perform filter with the high-resolution structures
for structure in high_resolution_structures:
    print(structure)
    model_url = structure.get("summary", {}).get("model_url")
    # Use wget or other methods to download the files
    download_file(model_url)
    print("Downloading:", model_url)
# Out:
# {'summary': {'model_identifier': '3d06', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3d06_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3d06', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2008-05-01', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.2'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# --2023-06-13 16:58:00--  https://www.ebi.ac.uk/pdbe/static/entry/3d06_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 393094 (384K) [text/plain]
# Saving to: ‘3d06_updated.cif.1’
#
# 3d06_updated.cif.1  100%[===================>] 383.88K   165KB/s    in 2.3s
#
# 2023-06-13 16:58:03 (165 KB/s) - ‘3d06_updated.cif.1’ saved [393094/393094]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/3d06_updated.cif
# {'summary': {'model_identifier': '5mhc', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5mhc_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5mhc', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-11-24', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.2'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'LYS-LEU-MET-PHE-LYS-TPO-GLU-GLY-PRO-ASP-SER-ASP', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CA', 'identifier_category': 'CCD', 'description': 'CALCIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}]}}
# --2023-06-13 16:58:03--  https://www.ebi.ac.uk/pdbe/static/entry/5mhc_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 766549 (749K) [text/plain]
# Saving to: ‘5mhc_updated.cif.1’
#
# 5mhc_updated.cif.1  100%[===================>] 748.58K   234KB/s    in 3.2s
#
# 2023-06-13 16:58:07 (234 KB/s) - ‘5mhc_updated.cif.1’ saved [766549/766549]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5mhc_updated.cif
# {'summary': {'model_identifier': '6ggc', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggc_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggc', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.24'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXN', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(furan-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:07--  https://www.ebi.ac.uk/pdbe/static/entry/6ggc_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 781519 (763K) [text/plain]
# Saving to: ‘6ggc_updated.cif.1’
#
# 6ggc_updated.cif.1  100%[===================>] 763.20K   299KB/s    in 2.6s
#
# 2023-06-13 16:58:11 (299 KB/s) - ‘6ggc_updated.cif.1’ saved [781519/781519]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6ggc_updated.cif
# {'summary': {'model_identifier': '6shz', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6shz_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6shz', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-08', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 311, 'coverage': Decimal('0.555'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.24'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}]}}
# --2023-06-13 16:58:11--  https://www.ebi.ac.uk/pdbe/static/entry/6shz_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 766701 (749K) [text/plain]
# Saving to: ‘6shz_updated.cif.1’
#
# 6shz_updated.cif.1  100%[===================>] 748.73K   258KB/s    in 2.9s
#
# 2023-06-13 16:58:15 (258 KB/s) - ‘6shz_updated.cif.1’ saved [766701/766701]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6shz_updated.cif
# {'summary': {'model_identifier': '4mzi', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/4mzi_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/4mzi', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2013-09-30', 'sequence_identity': Decimal('92.0'), 'uniprot_start': 93, 'uniprot_end': 292, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.25'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# --2023-06-13 16:58:15--  https://www.ebi.ac.uk/pdbe/static/entry/4mzi_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 260313 (254K) [text/plain]
# Saving to: ‘4mzi_updated.cif.1’
#
# 4mzi_updated.cif.1  100%[===================>] 254.21K   152KB/s    in 1.7s
#
# 2023-06-13 16:58:17 (152 KB/s) - ‘4mzi_updated.cif.1’ saved [260313/260313]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/4mzi_updated.cif
# {'summary': {'model_identifier': '6gge', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6gge_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6gge', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.25000506704'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EYE', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(5-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:18--  https://www.ebi.ac.uk/pdbe/static/entry/6gge_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 838533 (819K) [text/plain]
# Saving to: ‘6gge_updated.cif.1’
#
# 6gge_updated.cif.1  100%[===================>] 818.88K   302KB/s    in 2.7s
#
# 2023-06-13 16:58:21 (302 KB/s) - ‘6gge_updated.cif.1’ saved [838533/838533]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6gge_updated.cif
# {'summary': {'model_identifier': '3lw1', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3lw1_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3lw1', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2010-02-23', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 385, 'uniprot_end': 393, 'coverage': Decimal('0.023'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.28'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'peptide of Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}]}}
# --2023-06-13 16:58:21--  https://www.ebi.ac.uk/pdbe/static/entry/3lw1_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 574970 (561K) [text/plain]
# Saving to: ‘3lw1_updated.cif.1’
#
# 3lw1_updated.cif.1  100%[===================>] 561.49K   246KB/s    in 2.3s
#
# 2023-06-13 16:58:25 (246 KB/s) - ‘3lw1_updated.cif.1’ saved [574970/574970]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/3lw1_updated.cif
# {'summary': {'model_identifier': '8e7a', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8e7a_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8e7a', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-08-23', 'sequence_identity': Decimal('99.0'), 'uniprot_start': 93, 'uniprot_end': 312, 'coverage': Decimal('0.56'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}]}}
# --2023-06-13 16:58:25--  https://www.ebi.ac.uk/pdbe/static/entry/8e7a_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 385071 (376K) [text/plain]
# Saving to: ‘8e7a_updated.cif.1’
#
# 8e7a_updated.cif.1  100%[===================>] 376.05K   202KB/s    in 1.9s
#
# 2023-06-13 16:58:28 (202 KB/s) - ‘8e7a_updated.cif.1’ saved [385071/385071]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/8e7a_updated.cif
# {'summary': {'model_identifier': '5o1e', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1e_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1e', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GT', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-prop-2-enoxy-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:28--  https://www.ebi.ac.uk/pdbe/static/entry/5o1e_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 777026 (759K) [text/plain]
# Saving to: ‘5o1e_updated.cif.1’
#
# 5o1e_updated.cif.1  100%[===================>] 758.81K   296KB/s    in 2.6s
#
# 2023-06-13 16:58:32 (296 KB/s) - ‘5o1e_updated.cif.1’ saved [777026/777026]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5o1e_updated.cif
# {'summary': {'model_identifier': '6rl3', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6rl3_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6rl3', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-05-01', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.3'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'K48', 'identifier_category': 'CCD', 'description': '5-azanyl-4-phenyl-thiophene-2-carboximidamide', 'chain_ids': ['A']}]}}
# --2023-06-13 16:58:32--  https://www.ebi.ac.uk/pdbe/static/entry/6rl3_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534622 (522K) [text/plain]
# Saving to: ‘6rl3_updated.cif’
#
# 6rl3_updated.cif    100%[===================>] 522.09K   219KB/s    in 2.4s
#
# 2023-06-13 16:58:35 (219 KB/s) - ‘6rl3_updated.cif’ saved [534622/534622]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6rl3_updated.cif
# {'summary': {'model_identifier': '6ggb', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggb_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggb', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EDO', 'identifier_category': 'CCD', 'description': '1,2-ETHANEDIOL', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EPE', 'identifier_category': 'CCD', 'description': '4-(2-HYDROXYETHYL)-1-PIPERAZINE ETHANESULFONIC ACID', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXQ', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(4-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:35--  https://www.ebi.ac.uk/pdbe/static/entry/6ggb_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 793164 (775K) [text/plain]
# Saving to: ‘6ggb_updated.cif.1’
#
# 6ggb_updated.cif.1  100%[===================>] 774.57K   243KB/s    in 3.2s
#
# 2023-06-13 16:58:39 (243 KB/s) - ‘6ggb_updated.cif.1’ saved [793164/793164]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6ggb_updated.cif
# {'summary': {'model_identifier': '5o1c', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1c_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1c', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GZ', 'identifier_category': 'CCD', 'description': '5-(4-fluorophenyl)-3-iodanyl-2-oxidanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:39--  https://www.ebi.ac.uk/pdbe/static/entry/5o1c_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 779716 (761K) [text/plain]
# Saving to: ‘5o1c_updated.cif.1’
#
# 5o1c_updated.cif.1  100%[===================>] 761.44K   244KB/s    in 3.1s
#
# 2023-06-13 16:58:44 (244 KB/s) - ‘5o1c_updated.cif.1’ saved [779716/779716]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5o1c_updated.cif
# {'summary': {'model_identifier': '5o1h', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1h_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1h', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GN', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-propylsulfanyl-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:44--  https://www.ebi.ac.uk/pdbe/static/entry/5o1h_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 770359 (752K) [text/plain]
# Saving to: ‘5o1h_updated.cif’
#
# 5o1h_updated.cif    100%[===================>] 752.30K   277KB/s    in 2.7s
#
# 2023-06-13 16:58:47 (277 KB/s) - ‘5o1h_updated.cif’ saved [770359/770359]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5o1h_updated.cif
# {'summary': {'model_identifier': '7b4n', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/7b4n_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/7b4n', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2020-12-02', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 94, 'uniprot_end': 293, 'coverage': Decimal('0.509'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'FMT', 'identifier_category': 'CCD', 'description': 'FORMIC ACID', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QN8', 'identifier_category': 'CCD', 'description': '(2~{R})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QNN', 'identifier_category': 'CCD', 'description': '(2~{S})-2-methyl-1-azabicyclo[2.2.2]octan-3-one', 'chain_ids': ['A']}, {'entity_type': 'POLYMER', 'entity_poly_type': None, 'identifier': None, 'identifier_category': None, 'description': 'DNA target', 'chain_ids': ['B']}]}}
# --2023-06-13 16:58:47--  https://www.ebi.ac.uk/pdbe/static/entry/7b4n_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 529004 (517K) [text/plain]
# Saving to: ‘7b4n_updated.cif’
#
# 7b4n_updated.cif    100%[===================>] 516.61K   240KB/s    in 2.2s
#
# 2023-06-13 16:58:51 (240 KB/s) - ‘7b4n_updated.cif’ saved [529004/529004]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/7b4n_updated.cif
# {'summary': {'model_identifier': '6ggf', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6ggf_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6ggf', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2018-05-03', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.32000022323'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EXQ', 'identifier_category': 'CCD', 'description': '[9-ethyl-7-(4-methylthiophen-2-yl)carbazol-3-yl]methyl-methyl-azanium', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:51--  https://www.ebi.ac.uk/pdbe/static/entry/6ggf_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 839599 (820K) [text/plain]
# Saving to: ‘6ggf_updated.cif’
#
# 6ggf_updated.cif    100%[===================>] 819.92K   297KB/s    in 2.8s
#
# 2023-06-13 16:58:55 (297 KB/s) - ‘6ggf_updated.cif’ saved [839599/839599]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6ggf_updated.cif
# {'summary': {'model_identifier': '3zme', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/3zme_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/3zme', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2013-02-07', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'QC5', 'identifier_category': 'CCD', 'description': '2-(4-(4-fluorophenyl)-5-(1H-pyrrol-1-yl)-1H-pyrazol-1-yl)-N,N-dimethylethanamine', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:55--  https://www.ebi.ac.uk/pdbe/static/entry/3zme_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 794494 (776K) [text/plain]
# Saving to: ‘3zme_updated.cif’
#
# 3zme_updated.cif    100%[===================>] 775.87K   266KB/s    in 2.9s
#
# 2023-06-13 16:58:58 (266 KB/s) - ‘3zme_updated.cif’ saved [794494/794494]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/3zme_updated.cif
# {'summary': {'model_identifier': '5aok', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5aok_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5aok', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-09-10', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOH', 'identifier_category': 'CCD', 'description': '5-[2-cyclopropyl-5-(1H-pyrrol-1-yl)-1,3-oxazol-4-yl]-1H-1,2,3,4-tetrazole', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:58:59--  https://www.ebi.ac.uk/pdbe/static/entry/5aok_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 798458 (780K) [text/plain]
# Saving to: ‘5aok_updated.cif’
#
# 5aok_updated.cif    100%[===================>] 779.74K   259KB/s    in 3.0s
#
# 2023-06-13 16:59:03 (259 KB/s) - ‘5aok_updated.cif’ saved [798458/798458]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5aok_updated.cif
# {'summary': {'model_identifier': '5g4n', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5g4n_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5g4n', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2016-05-13', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'O83', 'identifier_category': 'CCD', 'description': '1-[9-(2,2-difluoroethyl)-9H-carbazol-3-yl]-N-methylmethanamine', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:59:03--  https://www.ebi.ac.uk/pdbe/static/entry/5g4n_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 777609 (759K) [text/plain]
# Saving to: ‘5g4n_updated.cif’
#
# 5g4n_updated.cif    100%[===================>] 759.38K   280KB/s    in 2.7s
#
# 2023-06-13 16:59:07 (280 KB/s) - ‘5g4n_updated.cif’ saved [777609/777609]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5g4n_updated.cif
# {'summary': {'model_identifier': '5o1g', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1g_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1g', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GK', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-(2-phenylethoxy)-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:59:07--  https://www.ebi.ac.uk/pdbe/static/entry/5o1g_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 771154 (753K) [text/plain]
# Saving to: ‘5o1g_updated.cif’
#
# 5o1g_updated.cif    100%[===================>] 753.08K   302KB/s    in 2.5s
#
# 2023-06-13 16:59:10 (302 KB/s) - ‘5o1g_updated.cif’ saved [771154/771154]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5o1g_updated.cif
# {'summary': {'model_identifier': '6v4f', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6v4f_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6v4f', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-11-27', 'sequence_identity': Decimal('81.0'), 'uniprot_start': 14, 'uniprot_end': 29, 'coverage': Decimal('0.041'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.35'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Stapled Peptide LSQETF(0EH)DLWKLE(MK8)EN(NH2)', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q7ZUW7', 'identifier_category': 'UNIPROT', 'description': 'Protein Mdm4', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'SO4', 'identifier_category': 'CCD', 'description': 'SULFATE ION', 'chain_ids': ['A']}]}}
# --2023-06-13 16:59:11--  https://www.ebi.ac.uk/pdbe/static/entry/6v4f_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 234073 (229K) [text/plain]
# Saving to: ‘6v4f_updated.cif’
#
# 6v4f_updated.cif    100%[===================>] 228.59K   137KB/s    in 1.7s
#
# 2023-06-13 16:59:14 (137 KB/s) - ‘6v4f_updated.cif’ saved [234073/234073]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6v4f_updated.cif
# {'summary': {'model_identifier': '5ab9', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5ab9_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5ab9', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2015-08-04', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.36'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'CELLULAR TUMOR ANTIGEN P53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '92O', 'identifier_category': 'CCD', 'description': '7-ethyl-3-(piperidin-4-yl)-1H-indole', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:59:14--  https://www.ebi.ac.uk/pdbe/static/entry/5ab9_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 785119 (767K) [text/plain]
# Saving to: ‘5ab9_updated.cif’
#
# 5ab9_updated.cif    100%[===================>] 766.72K   241KB/s    in 3.2s
#
# 2023-06-13 16:59:18 (241 KB/s) - ‘5ab9_updated.cif’ saved [785119/785119]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5ab9_updated.cif
# {'summary': {'model_identifier': '5o1d', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/5o1d_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/5o1d', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2017-05-18', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.36'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'GOL', 'identifier_category': 'CCD', 'description': 'GLYCEROL', 'chain_ids': ['B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': '9GW', 'identifier_category': 'CCD', 'description': '3-iodanyl-2-oxidanyl-5-propoxy-4-pyrrol-1-yl-benzoic acid', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:59:18--  https://www.ebi.ac.uk/pdbe/static/entry/5o1d_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 775947 (758K) [text/plain]
# Saving to: ‘5o1d_updated.cif’
#
# 5o1d_updated.cif    100%[===================>] 757.76K   237KB/s    in 3.2s
#
# 2023-06-13 16:59:22 (237 KB/s) - ‘5o1d_updated.cif’ saved [775947/775947]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/5o1d_updated.cif
# {'summary': {'model_identifier': '8a92', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8a92_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8a92', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-06-27', 'sequence_identity': Decimal('98.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.37'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'PEG', 'identifier_category': 'CCD', 'description': 'DI(HYDROXYETHYL)ETHER', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LE9', 'identifier_category': 'CCD', 'description': '4-bromanyl-5-(trifluoromethyl)-1H-pyrazol-3-amine', 'chain_ids': ['A', 'B']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'EPE', 'identifier_category': 'CCD', 'description': '4-(2-HYDROXYETHYL)-1-PIPERAZINE ETHANESULFONIC ACID', 'chain_ids': ['A', 'B']}]}}
# --2023-06-13 16:59:22--  https://www.ebi.ac.uk/pdbe/static/entry/8a92_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 851511 (832K) [text/plain]
# Saving to: ‘8a92_updated.cif’
#
# 8a92_updated.cif    100%[===================>] 831.55K   278KB/s    in 3.0s
#
# 2023-06-13 16:59:26 (278 KB/s) - ‘8a92_updated.cif’ saved [851511/851511]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/8a92_updated.cif
# ...
# --2023-06-13 17:02:18--  https://www.ebi.ac.uk/pdbe/static/entry/6rl4_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 527897 (516K) [text/plain]
# Saving to: ‘6rl4_updated.cif’
#
# 6rl4_updated.cif    100%[===================>] 515.52K   173KB/s    in 3.0s
#
# 2023-06-13 17:02:22 (173 KB/s) - ‘6rl4_updated.cif’ saved [527897/527897]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6rl4_updated.cif
# {'summary': {'model_identifier': '6rl6', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6rl6_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6rl6', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-05-01', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.6'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'K7Q', 'identifier_category': 'CCD', 'description': '~{N}-(2-azanylethyl)-2-carbamimidoyl-7-methoxy-1-benzothiophene-4-carboxamide', 'chain_ids': ['A']}]}}
# --2023-06-13 17:02:22--  https://www.ebi.ac.uk/pdbe/static/entry/6rl6_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 525618 (513K) [text/plain]
# Saving to: ‘6rl6_updated.cif’
#
# 6rl6_updated.cif    100%[===================>] 513.30K   188KB/s    in 2.7s
#
# 2023-06-13 17:02:26 (188 KB/s) - ‘6rl6_updated.cif’ saved [525618/525618]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6rl6_updated.cif
# {'summary': {'model_identifier': '6rm7', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6rm7_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6rm7', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-05-05', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.6'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'K92', 'identifier_category': 'CCD', 'description': '5-[3-(2-azanylethyl)imidazol-4-yl]-4-phenyl-thiophene-2-carboximidamide', 'chain_ids': ['A']}]}}
# --2023-06-13 17:02:26--  https://www.ebi.ac.uk/pdbe/static/entry/6rm7_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 532361 (520K) [text/plain]
# Saving to: ‘6rm7_updated.cif’
#
# 6rm7_updated.cif    100%[===================>] 519.88K   165KB/s    in 3.1s
#
# 2023-06-13 17:02:30 (165 KB/s) - ‘6rm7_updated.cif’ saved [532361/532361]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6rm7_updated.cif
# {'summary': {'model_identifier': '2foj', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/2foj_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/2foj', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2006-01-13', 'sequence_identity': Decimal('86.0'), 'uniprot_start': 361, 'uniprot_end': 367, 'coverage': Decimal('0.018'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.6'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'p53 peptide', 'chain_ids': ['B']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'Q93009', 'identifier_category': 'UNIPROT', 'description': 'Ubiquitin carboxyl-terminal hydrolase 7', 'chain_ids': ['A']}]}}
# --2023-06-13 17:02:30--  https://www.ebi.ac.uk/pdbe/static/entry/2foj_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194800 (190K) [text/plain]
# Saving to: ‘2foj_updated.cif’
#
# 2foj_updated.cif    100%[===================>] 190.23K   128KB/s    in 1.5s
#
# 2023-06-13 17:02:32 (128 KB/s) - ‘2foj_updated.cif’ saved [194800/194800]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/2foj_updated.cif
# {'summary': {'model_identifier': '8dc6', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/8dc6_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/8dc6', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2022-06-15', 'sequence_identity': Decimal('95.0'), 'uniprot_start': 94, 'uniprot_end': 312, 'coverage': Decimal('0.557'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.60000908706'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['A', 'B', 'C', 'D']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'ZN', 'identifier_category': 'CCD', 'description': 'ZINC ION', 'chain_ids': ['A', 'B', 'C', 'D']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'SO4', 'identifier_category': 'CCD', 'description': 'SULFATE ION', 'chain_ids': ['A', 'B', 'C', 'D']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['B', 'C']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'R4F', 'identifier_category': 'CCD', 'description': '1-(2-methylprop-2-enoyl)-1H-indole-3-carbaldehyde, bound form', 'chain_ids': ['A', 'B', 'C', 'D']}]}}
# --2023-06-13 17:02:32--  https://www.ebi.ac.uk/pdbe/static/entry/8dc6_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 986196 (963K) [text/plain]
# Saving to: ‘8dc6_updated.cif’
#
# 8dc6_updated.cif    100%[===================>] 963.08K   229KB/s    in 4.2s
#
# 2023-06-13 17:02:37 (229 KB/s) - ‘8dc6_updated.cif’ saved [986196/986196]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/8dc6_updated.cif
# {'summary': {'model_identifier': '6sip', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6sip_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6sip', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-10', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.6004470265'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LFB', 'identifier_category': 'CCD', 'description': '7-methoxy-1-benzothiophene-2-carboximidamide', 'chain_ids': ['A']}]}}
# --2023-06-13 17:02:37--  https://www.ebi.ac.uk/pdbe/static/entry/6sip_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 363760 (355K) [text/plain]
# Saving to: ‘6sip_updated.cif’
#
# 6sip_updated.cif    100%[===================>] 355.23K   155KB/s    in 2.3s
#
# 2023-06-13 17:02:41 (155 KB/s) - ‘6sip_updated.cif’ saved [363760/363760]
#
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6sip_updated.cif
# {'summary': {'model_identifier': '6siq', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6siq_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6siq', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-08-10', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.60121'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'LF5', 'identifier_category': 'CCD', 'description': '4-chloranyl-7-propan-2-yloxy-1-benzothiophene-2-carboximidamide', 'chain_ids': ['A']}]}}
# --2023-06-13 17:02:41--  https://www.ebi.ac.uk/pdbe/static/entry/6siq_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 361946 (353K) [text/plain]
# Saving to: ‘6siq_updated.cif’
#
# 6siq_updated.cif     60%[===========>        ] 215.17K   128KB/s               ^C
# Downloading: https://www.ebi.ac.uk/pdbe/static/entry/6siq_updated.cif
# {'summary': {'model_identifier': '6rk8', 'model_category': 'EXPERIMENTALLY DETERMINED', 'model_url': 'https://www.ebi.ac.uk/pdbe/static/entry/6rk8_updated.cif', 'model_format': 'MMCIF', 'model_type': None, 'model_page_url': 'https://www.ebi.ac.uk/pdbe/entry/pdb/6rk8', 'provider': 'PDBe', 'number_of_conformers': None, 'ensemble_sample_url': None, 'ensemble_sample_format': None, 'created': '2019-04-30', 'sequence_identity': Decimal('100.0'), 'uniprot_start': 382, 'uniprot_end': 393, 'coverage': Decimal('0.031'), 'experimental_method': 'X-RAY DIFFRACTION', 'resolution': Decimal('1.602'), 'confidence_type': None, 'confidence_version': None, 'confidence_avg_local_score': None, 'oligomeric_state': None, 'preferred_assembly_id': None, 'entities': [{'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P04637', 'identifier_category': 'UNIPROT', 'description': 'Cellular tumor antigen p53', 'chain_ids': ['P']}, {'entity_type': 'POLYMER', 'entity_poly_type': 'POLYPEPTIDE(L)', 'identifier': 'P31947', 'identifier_category': 'UNIPROT', 'description': '14-3-3 protein sigma', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'CL', 'identifier_category': 'CCD', 'description': 'CHLORIDE ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'MG', 'identifier_category': 'CCD', 'description': 'MAGNESIUM ION', 'chain_ids': ['A']}, {'entity_type': 'NON-POLYMER', 'entity_poly_type': None, 'identifier': 'K6N', 'identifier_category': 'CCD', 'description': '7-(3-azanyl-4-methyl-pyrazol-1-yl)-1-benzothiophene-2-carboximidamide', 'chain_ids': ['A']}]}}
# --2023-06-13 17:02:44--  https://www.ebi.ac.uk/pdbe/static/entry/6rk8_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 486287 (475K) [text/plain]
# Saving to: ‘6rk8_updated.cif’
#
# 6rk8_updated.cif     21%[===>                ] 103.55K  98.6KB/s

# %% [markdown]
# ##2.&nbsp; Sequence-Based Search

# %% [markdown]
# ##4.&nbsp; Download specific model
#
# Once you found the model/ models you need, you can customise this code to download the MMCIF file to Google Drive

# %%
#display widget
display(model_download)
# Out:
# Textarea(value='', description='Model identifier:', placeholder='Enter model identifier', style=DescriptionSty…

# %%
### Run this code to filter for specific model
for structure in structures:
  model = structure.get('summary', {}).get('model_identifier')
  if model == model_download.value:
    model_url = structure.get("summary", {}).get("model_url")

# Calling the download_file function to download a file from the specified model_url
download_file(model_url)
# Out:
# --2023-06-13 16:39:34--  https://www.ebi.ac.uk/pdbe/static/entry/6vqo_updated.cif
# Resolving www.ebi.ac.uk (www.ebi.ac.uk)... 193.62.193.80
# Connecting to www.ebi.ac.uk (www.ebi.ac.uk)|193.62.193.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2459022 (2.3M) [text/plain]
# Saving to: ‘6vqo_updated.cif’
#
# 6vqo_updated.cif    100%[===================>]   2.34M   533KB/s    in 5.5s
#
# 2023-06-13 16:39:41 (434 KB/s) - ‘6vqo_updated.cif’ saved [2459022/2459022]

# %% [markdown]
# # Bugs
#
# If you encounter any bugs, please report the issue to pdbekb_help@ebi.ac.uk.
